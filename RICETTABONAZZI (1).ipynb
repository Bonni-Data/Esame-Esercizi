# %% [markdown]
# # Spaghetti alla Carbonara

# %% [markdown]
# __________________________________________________

# %% [markdown]
# ![Spaghetti-alla-Carbonara_450x300_sp.webp](attachment:Spaghetti-alla-Carbonara_450x300_sp.webp)

# %% [markdown]
# __________________________________________________

# %% [markdown]
# ***Difficoltà***: Facile
# ***Preparazione***: 15 min
# ***Cottura***: 10 min
# ***Costo***: Basso

# %%
num= 1

# %%
Spaghetti= 80  
Guanciale= 37.5  
Tuorli_uova_medie= 1.5  
Pecorino_romano= 12.5

# %%
Spaghetti1= num*Spaghetti  
Guanciale1= num*Guanciale
Tuorli1= num*Tuorli_uova_medie
Pecorino1= num*Pecorino_romano

# %%
print("Ricetta per", num, "persone:")

# %%
print("Spaghetti:", Spaghetti1, "g")  
print("Guanciale:", Guanciale1, "g")  
print("Tuorli uova medie:", Tuorli1, "g")  
print("Pecorino romano:", Pecorino1, "g")
